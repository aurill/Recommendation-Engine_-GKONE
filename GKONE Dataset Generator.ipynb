# %%
# Cell 1: Setup and Imports

import pandas as pd
import numpy as np
import random
import string

# Setting random seed for reproducibility
np.random.seed(42)

# %%
# Cell 2: Parameters and Age Generation

# Define parameters
num_customers = 30000

# Define age percentiles
age_percentiles = [0.25, 0.5, 0.75, 1.0]
age_ranges = [18, 30, 45, 60, 70]
percentile_distribution = [0.3, 0.4, 0.2, 0.1]

# Generate ages based on percentiles
ages = []
for i in range(4):
    ages += list(np.random.randint(age_ranges[i], age_ranges[i+1], int(num_customers * percentile_distribution[i])))

# Ensure we have exactly num_customers by sampling if necessary
ages = np.random.choice(ages, num_customers, replace=False)

# %%
# Cell 3: Generate Genders, Locations, and Customer IDs

# Generate genders
genders = np.random.choice(['Male', 'Female'], num_customers, p=[0.5, 0.5])

# Generate locations
parishes_of_jamaica = ['Kingston', 'St. Andrew', 'St. Thomas', 'Portland', 'St. Mary', 'St. Ann', 'Trelawny', 'St. James', 'Hanover', 'Westmoreland', 'St. Elizabeth', 'Manchester', 'Clarendon', 'St. Catherine']
locations = np.random.choice(parishes_of_jamaica, num_customers)

# Function to generate CustomerID
def generate_customer_id():
    return 'sdv-id-' + ''.join(random.choices(string.ascii_letters + string.digits, k=6))

# Generate CustomerIDs
customer_ids = [generate_customer_id() for _ in range(num_customers)]

# %%
# Cell 4: Generate Income Levels, Education Levels, and Employment Status

# Generate income levels
income_levels = np.random.choice(['Low', 'Medium', 'High'], num_customers, p=[0.4, 0.4, 0.2])

# Generate education levels
education_levels = np.random.choice(['High School', 'College', 'Graduate'], num_customers, p=[0.4, 0.4, 0.2])

# Generate employment status
employment_status = np.random.choice(['Employed', 'Unemployed', 'Student', 'Retired'], num_customers, p=[0.5, 0.2, 0.2, 0.1])

# %%
# Cell 5: Assign Products Based on Age and Tenure

# Function to assign products based on age and tenure
def assign_products_by_age(age, tenure):
    products = []
    if age < age_ranges[1]:  # 0-25th percentile
        if np.random.rand() < 0.8:
            products.append('Remittances')
        if np.random.rand() < 0.9:
            products.append('PeerToPeer Sending')
        if np.random.rand() < 0.1:
            products.append('MotorInsurance')
        if np.random.rand() < 0.4:
            products.append('MarketPlace')
    elif age < age_ranges[2]:  # 25th-50th percentile
        if np.random.rand() < 0.9:
            products.append('Remittances')
        if np.random.rand() < 0.6:
            products.append('PeerToPeer Sending')
        if np.random.rand() < 0.7:
            products.append('MotorInsurance')
        if np.random.rand() < 0.7:
            products.append('MarketPlace')
    else:
        products = np.random.choice(product_types, np.random.randint(1, min(6, tenure + 1)), replace=False).tolist()
    return products

# Generate customer tenure
customer_tenure = np.random.randint(1, 7, num_customers)  # Tenure in years (1 to 6)

# Assign products to customers
product_types = ['PeerToPeer Sending', 'Remittances', 'BillPayments', 'MarketPlace', 'MotorInsurance']
customer_products = [assign_products_by_age(age, tenure) for age, tenure in zip(ages, customer_tenure)]

# %%
# Cell 6: Adjust Locations Based on Age Groups

# Adjust locations based on age groups
def adjust_locations_by_age(age):
    if age < age_ranges[2]:  # 0-50th percentile
        if np.random.rand() < 0.6:
            return np.random.choice(['Kingston', 'St. Andrew', 'St. Catherine'])
        else:
            return np.random.choice(parishes_of_jamaica)
    else:
        return np.random.choice(parishes_of_jamaica)

locations = [adjust_locations_by_age(age) for age in ages]

# %%
# Cell 7: Generate Transaction Data

# Function to generate transaction data based on age group, income level, and tenure
def generate_transaction_data_by_age_income(age, product_name, income_level, tenure):
    if age < age_ranges[1]:  # 0-25th percentile
        if product_name == 'Remittances':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(15, 33)
        elif product_name == 'PeerToPeer Sending':
            if income_level == 'Low':
                value = np.random.uniform(0, 5000)
            elif income_level == 'Medium':
                value = np.random.uniform(5000, 10000)
            else:  # High
                value = np.random.uniform(10000, 15000)
            frequency = np.random.randint(0, 20)
        elif product_name == 'MotorInsurance':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 10)
        elif product_name == 'MarketPlace':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
        else:
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
    elif age < age_ranges[2]:  # 25th-50th percentile
        if product_name == 'Remittances':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(35, 61)
        elif product_name == 'PeerToPeer Sending':
            if income_level == 'Low':
                value = np.random.uniform(0, 10000)
            elif income_level == 'Medium':
                value = np.random.uniform(10000, 20000)
            else:  # High
                value = np.random.uniform(20000, 25000)
            frequency = np.random.randint(0, 20)
        elif product_name == 'MotorInsurance':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
        elif product_name == 'MarketPlace':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
        else:
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
    elif age < age_ranges[3]:  # 50th-75th percentile
        if product_name == 'Remittances':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(15, 33)
        elif product_name == 'PeerToPeer Sending':
            if income_level == 'Low':
                value = np.random.uniform(0, 15000)
            elif income_level == 'Medium':
                value = np.random.uniform(15000, 20000)
            else:  # High
                value = np.random.uniform(20000, 25000)
            frequency = np.random.randint(0, 20)
        elif product_name == 'MotorInsurance':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 10)
        elif product_name == 'MarketPlace':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
        else:
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
    else:  # 75th-100th percentile
        if product_name == 'Remittances':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(35, 61)
        elif product_name == 'PeerToPeer Sending':
            if income_level == 'Low':
                value = np.random.uniform(0, 15000)
            elif income_level == 'Medium':
                value = np.random.uniform(15000, 20000)
            else:  # High
                value = np.random.uniform(20000, 25000)
            frequency = np.random.randint(0, 20)
        elif product_name == 'MotorInsurance':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
        elif product_name == 'MarketPlace':
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
        else:
            value = np.random.uniform(0, 2000)
            frequency = np.random.randint(0, 20)
    # Adjust values based on tenure
    value = value * (1 + 0.1 * (tenure - 1))
    return value, frequency

# Generate transaction values and frequencies based on age group, income level, and tenure
def generate_transaction_data(customers_ages, customers_products, product_name, income_levels, tenures):
    values = []
    frequencies = []
    for age, products, income, tenure in zip(customers_ages, customers_products, income_levels, tenures):
        if product_name in products:
            value, frequency = generate_transaction_data_by_age_income(age, product_name, income, tenure)
            values.append(value)
            frequencies.append(frequency)
        else:
            values.append(0)
            frequencies.append(0)
    return values, frequencies

# Generate data for each product type
peer_to_peer_values, peer_to_peer_freqs = generate_transaction_data(ages, customer_products, 'PeerToPeer Sending', income_levels, customer_tenure)
remittances_values, remittances_freqs = generate_transaction_data(ages, customer_products, 'Remittances', income_levels, customer_tenure)
bill_payments_values, bill_payments_freqs = generate_transaction_data(ages, customer_products, 'BillPayments', income_levels, customer_tenure)
marketplace_values, marketplace_freqs = generate_transaction_data(ages, customer_products, 'MarketPlace', income_levels, customer_tenure)

# %%
# Cell 8: Adjust Linked Bank Account Values

# Adjust linked bank account values
def adjust_linked_bank_values(ages, income_levels, tenures):
    values = []
    for age, income, tenure in zip(ages, income_levels, tenures):
        if age_ranges[1] <= age < age_ranges[2]:  # 25th-50th percentile
            if income == 'High' and tenure >= 4:
                value = np.random.uniform(200000, 300000)
            else:
                value = np.random.uniform(20000, 100000)
        else:
            value = np.random.uniform(20000, 50000)
        values.append(value)
    return values

linked_bank_values = adjust_linked_bank_values(ages, income_levels, customer_tenure)

# %%
# Cell 9: Generate Activity Levels

# Generate activity level based on employment status
def generate_activity_level(employment_status):
    if employment_status == 'Employed':
        return np.random.randint(10, 30)
    elif employment_status == 'Student':
        return np.random.randint(15, 25)
    elif employment_status == 'Unemployed':
        return np.random.randint(5, 15)
    else:  # Retired
        return np.random.randint(5, 20)

activity_level = [generate_activity_level(status) for status in employment_status]

# %%
# Cell 10: Create and Save the DataFrame

# Create DataFrame
data = {
    'CustomerID': customer_ids,
    'Age': ages,
    'Gender': genders,
    'Location': locations,
    'LinkedBankAccountMonthlyValue': linked_bank_values,
    'ProductType': customer_products,
    'PeerToPeer_MonthlyTransValue': peer_to_peer_values,
    'Remittances_MonthlyTransValue': remittances_values,
    'BillPayments_MonthlyTransValue': bill_payments_values,
    'RemittancesFreq_Monthly': remittances_freqs,
    'BillPaymentsFreq_Monthly': bill_payments_freqs,
    'MarketPlaceFreq_Monthly': marketplace_freqs,
    'PeerToPeerFreq_Monthly': peer_to_peer_freqs,
    'IncomeLevel': income_levels,
    'EducationLevel': education_levels,
    'EmploymentStatus': employment_status,
    'CustomerTenure': customer_tenure,
    'ActivityLevel': activity_level
}

df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('/content/Updated_GKONE_Synthetic_Dataset.csv', index=False)

# Display the DataFrame
df.head(50)
# Out:
#        CustomerID  Age  Gender       Location  LinkedBankAccountMonthlyValue  \
# 0   sdv-id-IN7ITT   25  Female       Trelawny                   46601.668557
# 1   sdv-id-4hnCCT   43  Female  St. Catherine                   64044.610963
# 2   sdv-id-iOIToj   42  Female     St. Andrew                   93085.837759
# 3   sdv-id-8TvnUL   69    Male       Kingston                   22944.196442
# 4   sdv-id-QijYGa   27  Female     St. Andrew                   47014.788265
# 5   sdv-id-PpmeEb   44    Male       Kingston                   56340.738768
# 6   sdv-id-qnYvws   56  Female  St. Elizabeth                   20663.810887
# 7   sdv-id-EsLm1l   31    Male       Kingston                   23845.991525
# 8   sdv-id-BuRnMD   42  Female  St. Catherine                  292507.231778
# 9   sdv-id-b3VsIs   19    Male        St. Ann                   36838.764974
# 10  sdv-id-ziWXT0   33  Female      Clarendon                   39139.891882
# 11  sdv-id-3ZtxrL   50    Male     St. Thomas                   39528.928712
# 12  sdv-id-KLrPCC   39    Male       Trelawny                   25392.031064
# 13  sdv-id-FTH5Tf   26  Female       Kingston                   49315.393321
# 14  sdv-id-g9BlmW   29    Male       St. Mary                   44546.613230
# 15  sdv-id-6sCRar   22    Male     Manchester                   33886.236183
# 16  sdv-id-a9UD25   37    Male  St. Catherine                   55293.894104
# 17  sdv-id-V24gWr   24  Female      Clarendon                   30465.726446
# 18  sdv-id-x5tVUb   21    Male  St. Catherine                   44879.011092
# 19  sdv-id-yREGkM   40    Male     St. Andrew                   29458.412124
# 20  sdv-id-vgt7oT   35  Female  St. Catherine                   77210.987893
# 21  sdv-id-XnNjd0   47    Male       Portland                   24595.394263
# 22  sdv-id-dcDz2w   22    Male       Kingston                   34983.162739
# 23  sdv-id-9xZ0Xt   25  Female       Trelawny                   32245.291405
# 24  sdv-id-rZNM0s   18    Male  St. Catherine                   49745.056989
# 25  sdv-id-LFIseN   39  Female       Kingston                   53419.923578
# 26  sdv-id-dVlpRb   23  Female       Kingston                   49589.897620
# 27  sdv-id-fJBQGx   20  Female     St. Andrew                   33223.965235
# 28  sdv-id-WTHB5i   34  Female     St. Andrew                  247157.858904
# 29  sdv-id-wH4eNI   31    Male     St. Andrew                  223141.946414
# 30  sdv-id-m9F7cg   30  Female        St. Ann                   87897.660168
# 31  sdv-id-DUAZue   18  Female       Kingston                   40255.381143
# 32  sdv-id-O2FwfI   28    Male       Kingston                   49880.008884
# 33  sdv-id-neohMW   43    Male      St. James                   62517.232627
# 34  sdv-id-ZSwEAT   28  Female  St. Catherine                   32236.867861
# 35  sdv-id-ZSnQdK   53    Male        Hanover                   34394.995123
# 36  sdv-id-1D0Nt3   31    Male  St. Catherine                   49122.436387
# 37  sdv-id-IT56zH   49  Female     St. Andrew                   45518.885848
# 38  sdv-id-nJT42b   46  Female   Westmoreland                   32466.273207
# 39  sdv-id-JPvtoe   46    Male  St. Elizabeth                   22129.284912
# 40  sdv-id-8C7k53   63    Male     St. Andrew                   36438.882689
# 41  sdv-id-yB32gl   42    Male     St. Andrew                  299209.155971
# 42  sdv-id-DtwUT2   29  Female  St. Catherine                   46960.041920
# 43  sdv-id-UOziz6   66  Female     Manchester                   35525.310789
# 44  sdv-id-OvM6Xv   40    Male       Kingston                   49108.990559
# 45  sdv-id-tOJWO9   44  Female       Kingston                   54511.806273
# 46  sdv-id-9Q3X6G   37    Male       Kingston                   69964.676820
# 47  sdv-id-F8Bydu   47  Female   Westmoreland                   30760.205636
# 48  sdv-id-1jKlvV   50    Male        St. Ann                   46462.880540
# 49  sdv-id-0MFDpo   30  Female      Clarendon                   28446.500435
#
#                                           ProductType  \
# 0      [Remittances, PeerToPeer Sending, MarketPlace]
# 1      [Remittances, PeerToPeer Sending, MarketPlace]
# 2   [Remittances, PeerToPeer Sending, MotorInsurance]
# 3                                [PeerToPeer Sending]
# 4                                [PeerToPeer Sending]
# 5      [Remittances, PeerToPeer Sending, MarketPlace]
# 6                                       [Remittances]
# 7          [Remittances, MotorInsurance, MarketPlace]
# 8   [Remittances, PeerToPeer Sending, MotorInsuran...
# 9                   [Remittances, PeerToPeer Sending]
# 10                                      [Remittances]
# 11                                      [Remittances]
# 12         [Remittances, MotorInsurance, MarketPlace]
# 13                  [Remittances, PeerToPeer Sending]
# 14                  [PeerToPeer Sending, MarketPlace]
# 15                  [Remittances, PeerToPeer Sending]
# 16  [Remittances, PeerToPeer Sending, MotorInsuran...
# 17                  [Remittances, PeerToPeer Sending]
# 18                  [PeerToPeer Sending, MarketPlace]
# 19         [Remittances, MotorInsurance, MarketPlace]
# 20  [Remittances, PeerToPeer Sending, MotorInsuran...
# 21                                     [BillPayments]
# 22                  [Remittances, PeerToPeer Sending]
# 23                               [PeerToPeer Sending]
# 24                  [Remittances, PeerToPeer Sending]
# 25     [Remittances, PeerToPeer Sending, MarketPlace]
# 26                  [Remittances, PeerToPeer Sending]
# 27                  [PeerToPeer Sending, MarketPlace]
# 28                                      [Remittances]
# 29     [Remittances, PeerToPeer Sending, MarketPlace]
# 30                                      [MarketPlace]
# 31     [Remittances, PeerToPeer Sending, MarketPlace]
# 32     [Remittances, PeerToPeer Sending, MarketPlace]
# 33  [Remittances, PeerToPeer Sending, MotorInsurance]
# 34     [Remittances, PeerToPeer Sending, MarketPlace]
# 35                               [PeerToPeer Sending]
# 36  [Remittances, PeerToPeer Sending, MotorInsuran...
# 37                        [BillPayments, MarketPlace]
# 38               [MotorInsurance, PeerToPeer Sending]
# 39         [Remittances, MarketPlace, MotorInsurance]
# 40    [PeerToPeer Sending, BillPayments, Remittances]
# 41     [Remittances, PeerToPeer Sending, MarketPlace]
# 42                         [Remittances, MarketPlace]
# 43                  [Remittances, PeerToPeer Sending]
# 44  [PeerToPeer Sending, MotorInsurance, MarketPlace]
# 45         [Remittances, MotorInsurance, MarketPlace]
# 46  [Remittances, PeerToPeer Sending, MotorInsuran...
# 47  [BillPayments, MarketPlace, MotorInsurance, Re...
# 48  [MarketPlace, BillPayments, Remittances, Motor...
# 49         [Remittances, MotorInsurance, MarketPlace]
#
#     PeerToPeer_MonthlyTransValue  Remittances_MonthlyTransValue  \
# 0                    5276.880318                    1238.053843
# 1                   28503.972689                    2965.286891
# 2                   11195.330762                    1468.833594
# 3                      89.461759                       0.000000
# 4                    7674.463699                       0.000000
# 5                    5526.267647                    1461.346428
# 6                       0.000000                    1852.559755
# 7                       0.000000                    1602.324331
# 8                   30982.728497                     871.447039
# 9                    6871.776559                    1891.206707
# 10                      0.000000                    1989.090687
# 11                      0.000000                    1972.292266
# 12                      0.000000                     853.773225
# 13                  20582.505198                     999.734750
# 14                  14060.532913                       0.000000
# 15                  16010.221201                     228.402248
# 16                  12293.461914                     750.755995
# 17                  10990.037031                    2069.650889
# 18                   8889.081390                       0.000000
# 19                      0.000000                    1558.541869
# 20                  23012.204580                     194.338338
# 21                      0.000000                       0.000000
# 22                  20820.284949                     746.620095
# 23                  15961.064635                       0.000000
# 24                   4522.415804                     242.000516
# 25                  19482.666442                     917.147107
# 26                  22255.140831                      36.118986
# 29                         0                       19                      13
# 30                         0                        2                       0
# 31                         0                        3                      16
# 32                         0                        8                       8
# 33                         0                        0                       3
# 34                         0                        2                       2
# 35                         0                        0                      17
# 36                         0                        7                       3
# 37                         3                       19                       0
# 38                         0                        0                      13
# 39                         0                        5                       0
# 40                        15                        0                       1
# 41                         0                       16                       1
# 42                         0                        2                       0
# 43                         0                        0                       8
# 44                         0                        4                      14
# 45                         0                        1                       0
# 46                         0                        6                      15
# 47                         8                       17                       9
# 48                         1                        3                       0
# 49                         0                        6                       0
#
#    IncomeLevel EducationLevel EmploymentStatus  CustomerTenure  ActivityLevel
# 0          Low    High School         Employed               4             17
# 1       Medium       Graduate          Student               6             24
# 2          Low        College         Employed               5             14
# 3          Low       Graduate       Unemployed               1              5
# 4       Medium        College         Employed               1             21
# 5          Low        College         Employed               1             19
# 6       Medium    High School       Unemployed               1              5
# 7         High        College         Employed               3             22
# 8         High    High School       Unemployed               4             13
# 9       Medium        College          Retired               1             15
# 10         Low    High School          Retired               5              8
# 11      Medium       Graduate          Student               1             18
# 12         Low    High School         Employed               1             22
# 13        High    High School         Employed               6             27
# 14        High       Graduate          Retired               1             12
# 15        High    High School         Employed               3             23
# 16      Medium        College         Employed               2             26
# 17      Medium       Graduate          Student               6             19
# 18      Medium    High School         Employed               3             14
# 19         Low    High School          Retired               5             13
# 20        High    High School         Employed               1             17
# 21         Low    High School         Employed               6             18
# 22        High        College       Unemployed               6              8
# 23        High       Graduate       Unemployed               2              7
# 24         Low        College       Unemployed               4              8
# 25      Medium       Graduate         Employed               4             23
# 26        High    High School          Student               6             22
# 27        High       Graduate         Employed               1             28
# 28        High        College         Employed               6             26
# 29        High       Graduate       Unemployed               5              9
# 30        High       Graduate         Employed               1             22
# 31        High       Graduate       Unemployed               4              8
# 32      Medium    High School         Employed               4             20
# 33         Low        College          Student               3             18
# 34      Medium    High School         Employed               4             19
# 35         Low    High School         Employed               2             10
# 36      Medium        College         Employed               6             22
# 37      Medium       Graduate       Unemployed               5             11
# 38        High    High School         Employed               4             20
# 39         Low       Graduate          Student               4             22
# 40      Medium       Graduate       Unemployed               3              8
# 41        High    High School         Employed               6             27
# 42      Medium    High School         Employed               4             19
# 43      Medium    High School          Student               3             20
# 44      Medium        College         Employed               3             25
# 45         Low    High School       Unemployed               3              8
# 46         Low    High School       Unemployed               6             11
# 47      Medium    High School          Student               6             15
# 48         Low        College         Employed               6             17
# 49         Low       Graduate          Student               6             16

# %%
# Display the DataFrame
df.head(50)
# Out:
#        CustomerID  Age  Gender       Location  LinkedBankAccountMonthlyValue  \
# 0   sdv-id-IN7ITT   25  Female       Trelawny                   46601.668557
# 1   sdv-id-4hnCCT   43  Female  St. Catherine                   64044.610963
# 2   sdv-id-iOIToj   42  Female     St. Andrew                   93085.837759
# 3   sdv-id-8TvnUL   69    Male       Kingston                   22944.196442
# 4   sdv-id-QijYGa   27  Female     St. Andrew                   47014.788265
# 5   sdv-id-PpmeEb   44    Male       Kingston                   56340.738768
# 49  sdv-id-0MFDpo   30  Female      Clarendon                   28446.500435
#
#                                           ProductType  \
# 0      [Remittances, PeerToPeer Sending, MarketPlace]
# 1      [Remittances, PeerToPeer Sending, MarketPlace]
# 2   [Remittances, PeerToPeer Sending, MotorInsurance]
# 3                                [PeerToPeer Sending]
# 4                                [PeerToPeer Sending]
# 5      [Remittances, PeerToPeer Sending, MarketPlace]
# 6                                       [Remittances]
# 7          [Remittances, MotorInsurance, MarketPlace]
# 8   [Remittances, PeerToPeer Sending, MotorInsuran...
# 9                   [Remittances, PeerToPeer Sending]
# 10                                      [Remittances]
# 11                                      [Remittances]
# 12         [Remittances, MotorInsurance, MarketPlace]
# 13                  [Remittances, PeerToPeer Sending]
# 14                  [PeerToPeer Sending, MarketPlace]
# 15                  [Remittances, PeerToPeer Sending]
# 16  [Remittances, PeerToPeer Sending, MotorInsuran...
# 17                  [Remittances, PeerToPeer Sending]
# 18                  [PeerToPeer Sending, MarketPlace]
# 19         [Remittances, MotorInsurance, MarketPlace]
# 20  [Remittances, PeerToPeer Sending, MotorInsuran...
# 21                                     [BillPayments]
# 22                  [Remittances, PeerToPeer Sending]
# 23                               [PeerToPeer Sending]
# 24                  [Remittances, PeerToPeer Sending]
# 25     [Remittances, PeerToPeer Sending, MarketPlace]
# 26                  [Remittances, PeerToPeer Sending]
# 27                  [PeerToPeer Sending, MarketPlace]
# 28                                      [Remittances]
# 29     [Remittances, PeerToPeer Sending, MarketPlace]
# 30                                      [MarketPlace]
# 31     [Remittances, PeerToPeer Sending, MarketPlace]
# 32     [Remittances, PeerToPeer Sending, MarketPlace]
# 33  [Remittances, PeerToPeer Sending, MotorInsurance]
# 34     [Remittances, PeerToPeer Sending, MarketPlace]
# 35                               [PeerToPeer Sending]
# 36  [Remittances, PeerToPeer Sending, MotorInsuran...
# 37                        [BillPayments, MarketPlace]
# 38               [MotorInsurance, PeerToPeer Sending]
# 39         [Remittances, MarketPlace, MotorInsurance]
# 40    [PeerToPeer Sending, BillPayments, Remittances]
# 41     [Remittances, PeerToPeer Sending, MarketPlace]
# 42                         [Remittances, MarketPlace]
# 43                  [Remittances, PeerToPeer Sending]
# 44  [PeerToPeer Sending, MotorInsurance, MarketPlace]
# 45         [Remittances, MotorInsurance, MarketPlace]
# 46  [Remittances, PeerToPeer Sending, MotorInsuran...
# 47  [BillPayments, MarketPlace, MotorInsurance, Re...
# 48  [MarketPlace, BillPayments, Remittances, Motor...
# 49         [Remittances, MotorInsurance, MarketPlace]
#
#     PeerToPeer_MonthlyTransValue  Remittances_MonthlyTransValue  \
# 0                    5276.880318                    1238.053843
# 1                   28503.972689                    2965.286891
# 2                   11195.330762                    1468.833594
# 3                      89.461759                       0.000000
# 4                    7674.463699                       0.000000
# 5                    5526.267647                    1461.346428
# 6                       0.000000                    1852.559755
# 7                       0.000000                    1602.324331
# 8                   30982.728497                     871.447039
# 9                    6871.776559                    1891.206707
# 10                      0.000000                    1989.090687
# 9                          0                        0                      12
# 10                         0                        0                       0
# 11                         0                        0                       0
# 12                         0                        1                       0
# 13                         0                        0                      17
# 14                         0                       19                       3
# 15                         0                        0                      17
# 16                         0                       17                      16
# 17                         0                        0                       2
# 18                         0                       17                       1
# 19                         0                        3                       0
# 20                         0                       12                      11
# 21                         1                        0                       0
# 22                         0                        0                       5
# 23                         0                        0                      18
# 24                         0                        0                      14
# 25                         0                       18                      13
# 26                         0                        0                      14
# 27                         0                        5                      11
# 28                         0                        0                       0
# 29                         0                       19                      13
# 30                         0                        2                       0
# 31                         0                        3                      16
# 32                         0                        8                       8
# 33                         0                        0                       3
# 34                         0                        2                       2
# 35                         0                        0                      17
# 36                         0                        7                       3
# 37                         3                       19                       0
# 38                         0                        0                      13
# 39                         0                        5                       0
# 40                        15                        0                       1
# 41                         0                       16                       1
# 42                         0                        2                       0
# 43                         0                        0                       8
# 44                         0                        4                      14
# 45                         0                        1                       0
# 46                         0                        6                      15
# 47                         8                       17                       9
# 48                         1                        3                       0
# 49                         0                        6                       0
#
#    IncomeLevel EducationLevel EmploymentStatus  CustomerTenure  ActivityLevel
# 0          Low    High School         Employed               4             17
# 1       Medium       Graduate          Student               6             24
# 2          Low        College         Employed               5             14
# 3          Low       Graduate       Unemployed               1              5
# 4       Medium        College         Employed               1             21
# 5          Low        College         Employed               1             19
# 6       Medium    High School       Unemployed               1              5
# 7         High        College         Employed               3             22
# 8         High    High School       Unemployed               4             13
# 9       Medium        College          Retired               1             15
# 10         Low    High School          Retired               5              8
# 11      Medium       Graduate          Student               1             18
# 12         Low    High School         Employed               1             22
# 13        High    High School         Employed               6             27
# 14        High       Graduate          Retired               1             12
# 15        High    High School         Employed               3             23
# 16      Medium        College         Employed               2             26
# 17      Medium       Graduate          Student               6             19
# 18      Medium    High School         Employed               3             14
# 19         Low    High School          Retired               5             13
# 20        High    High School         Employed               1             17
# 21         Low    High School         Employed               6             18
# 22        High        College       Unemployed               6              8
# 23        High       Graduate       Unemployed               2              7
# 24         Low        College       Unemployed               4              8
# 25      Medium       Graduate         Employed               4             23
# 26        High    High School          Student               6             22
# 27        High       Graduate         Employed               1             28
# 28        High        College         Employed               6             26
# 29        High       Graduate       Unemployed               5              9
# 30        High       Graduate         Employed               1             22
# 31        High       Graduate       Unemployed               4              8
# 32      Medium    High School         Employed               4             20
# 33         Low        College          Student               3             18
# 34      Medium    High School         Employed               4             19
# 35         Low    High School         Employed               2             10
# 36      Medium        College         Employed               6             22
# 37      Medium       Graduate       Unemployed               5             11
# 38        High    High School         Employed               4             20
# 39         Low       Graduate          Student               4             22
# 40      Medium       Graduate       Unemployed               3              8
# 41        High    High School         Employed               6             27
# 42      Medium    High School         Employed               4             19
# 43      Medium    High School          Student               3             20
# 44      Medium        College         Employed               3             25
# 45         Low    High School       Unemployed               3              8
# 46         Low    High School       Unemployed               6             11
# 47      Medium    High School          Student               6             15
# 48         Low        College         Employed               6             17
# 49         Low       Graduate          Student               6             16
